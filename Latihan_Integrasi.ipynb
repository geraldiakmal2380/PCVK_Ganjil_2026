# %% [markdown]
# <a href="https://colab.research.google.com/github/geraldiakmal2380/PCVK_Ganjil_2026/blob/main/Latihan_Integrasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import panda as pd
import cv2 as cv
